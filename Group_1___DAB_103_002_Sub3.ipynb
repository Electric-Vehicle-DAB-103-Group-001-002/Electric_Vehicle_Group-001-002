# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
project_dir = 'drive/MyDrive/DAB103-DEMO/DAB103_Project/'
project_dir
# Out:
# 'drive/MyDrive/DAB103-DEMO/DAB103_Project/'

# %%
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pandas.core.dtypes.cast import convert_dtypes

# %%
print('\nNamed with wildcard *:')
for name in glob.glob(project_dir+'*'):
  print(name)
# Out:
# Named with wildcard *:
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2012-2022 Battery Electric Vehicles.csv
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2012-2022 Plug-in Hybrid Electric Vehicles.csv
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2012-2022 Plug-in Hybrid Electric Vehicles.xlsx
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2022 Gas Powered Fuel Consumption Ratings.xlsx
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2022 Gas Powered Fuel Consumption Ratings.csv
# drive/MyDrive/DAB103-DEMO/DAB103_Project/NEWYORK_DATA.csv
# drive/MyDrive/DAB103-DEMO/DAB103_Project/Consumers Preference Towards Vehicles.ipynb
# drive/MyDrive/DAB103-DEMO/DAB103_Project/CO2 Emission.ipynb
# drive/MyDrive/DAB103-DEMO/DAB103_Project/Fuel_Comparison.ipynb
# drive/MyDrive/DAB103-DEMO/DAB103_Project/Text.ipynb
# drive/MyDrive/DAB103-DEMO/DAB103_Project/Group 1 _ DAB 103-002_Sub1.ipynb
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2012-2022 Battery Electric Vehicles.xlsx
# ...

# %%
print(project_dir+'*')
# Out:
# drive/MyDrive/DAB103-DEMO/DAB103_Project/*

# %%
print('\nNamed with wildcard *:')
for name in glob.glob(project_dir+'*.csv'):
  print(name)
# Out:
# Named with wildcard *:
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2012-2022 Battery Electric Vehicles.csv
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2012-2022 Plug-in Hybrid Electric Vehicles.csv
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2022 Gas Powered Fuel Consumption Ratings.csv
# drive/MyDrive/DAB103-DEMO/DAB103_Project/NEWYORK_DATA.csv

# %%
print('\nNamed with wildcard *:')
for name in glob.glob(project_dir+'*.xlsx'):
  print(name)
# Out:
# Named with wildcard *:
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2012-2022 Plug-in Hybrid Electric Vehicles.xlsx
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2022 Gas Powered Fuel Consumption Ratings.xlsx
# drive/MyDrive/DAB103-DEMO/DAB103_Project/MY2012-2022 Battery Electric Vehicles.xlsx
# drive/MyDrive/DAB103-DEMO/DAB103_Project/Battery_Operated.xlsx
# drive/MyDrive/DAB103-DEMO/DAB103_Project/Hybrid_Vehicles.xlsx
# drive/MyDrive/DAB103-DEMO/DAB103_Project/Lease_Purchase.xlsx
# drive/MyDrive/DAB103-DEMO/DAB103_Project/Gas_Powered.xlsx

# %%
Gas_Powered = pd.read_excel(project_dir+ 'MY2022 Gas Powered Fuel Consumption Ratings.xlsx')
Battery_Operated = pd.read_excel(project_dir+ 'MY2012-2022 Battery Electric Vehicles.xlsx')
Hybrid_Vehicles = pd.read_excel(project_dir+ 'MY2012-2022 Plug-in Hybrid Electric Vehicles.xlsx')
Lease_Purchase = pd.read_csv(project_dir+ 'NEWYORK_DATA.csv')

# %% [markdown]
# MY2012-2022 Battery Electric Vehicles.xlsx
#
# Battery_Operated

# %%
Battery_Operated
# Out:
#              Model                                               Make  \
# 0             Year                                                NaN
# 1           2012.0                                         Mitsubishi
# 2           2012.0                                             Nissan
# 3           2013.0                                               Ford
# 4           2013.0                                         Mitsubishi
# ..             ...                                                ...
# 321  CO2 emissions  the tailpipe emissions of carbon dioxide (in g...
# 322     CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 323    Smog rating  the tailpipe emissions of smog-forming polluta...
# 324          Range  the estimated driving distance (in kilometres)...
# 325  Recharge time  the estimated time (in hours) to fully recharg...
#
#             Model.1 Vehicle Class  Motor Transmission  Fuel  \
# 0               NaN           NaN   (kW)          NaN  Type
# ...

# %%
Battery_Operated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model          322 non-null    object
#  1   Make           320 non-null    object
#  2   Model.1        310 non-null    object
#  3   Vehicle Class  310 non-null    object
#  4   Motor          311 non-null    object
#  5   Transmission   310 non-null    object
#  6   Fuel           311 non-null    object
#  7   Consumption    311 non-null    object
#  8   Unnamed: 8     311 non-null    object
#  9   Unnamed: 9     311 non-null    object
#  10  Unnamed: 10    311 non-null    object
#  11  Unnamed: 11    311 non-null    object
#  12  Unnamed: 12    311 non-null    object
#  13  Range          311 non-null    object
#  14  CO2 Emissions  311 non-null    object
#  15  CO2            277 non-null    object
#  16  Smog           250 non-null    object
# ...

# %%
Battery_Operated.rename(columns = {'Model': 'Model Year', 
                                    'Model.1': 'Model',
                                    'Engine Size': 'Engine Size (L)',
                                    'Fuel': 'Fuel Type',
                                    'Consumption': 'Eletric Consumption City(kWh100km)',
                                    'Unnamed: 8': 'Eletric Consumption Hwy(kWh/100km)',
                                    'Unnamed: 9': 'Eletric Consumption Comb(kWh/100km)',
                                    'Unnamed: 10': 'Fuel Consumption City(Le/100km)',
                                    'Unnamed: 11': 'Fuel Consumption Hwy(Le/100km)',
                                    'Unnamed: 12': 'Fuel Consumption Comb(Le/100km)',
                                    'Range': 'Range(km)',
                                    'CO2 Emissions': 'CO2 Emissions (g/km)',
                                    'CO2 ': 'CO2 Rating',
                                    'Smog': 'Smog Rating',
                                    'Recharge': 'Recharge time(h)'}, inplace = True)
#to rename the columns

Battery_Operated.columns = Battery_Operated.columns.str.replace(' ', "_")

Battery_Operated.drop(Gas_Powered.index[0:1], inplace = True); Battery_Operated
# Out:
#         Model_Year                                               Make  \
# 1           2012.0                                         Mitsubishi
# 2           2012.0                                             Nissan
# 3           2013.0                                               Ford
# 4           2013.0                                         Mitsubishi
# 5           2013.0                                             Nissan
# ..             ...                                                ...
# 321  CO2 emissions  the tailpipe emissions of carbon dioxide (in g...
# 322     CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 323    Smog rating  the tailpipe emissions of smog-forming polluta...
# 324          Range  the estimated driving distance (in kilometres)...
# 325  Recharge time  the estimated time (in hours) to fully recharg...
#
#               Model Vehicle_Class  Motor Transmission Fuel_Type  \
# ...

# %%
Battery_Operated.isnull().sum()
# Out:
# Model_Year                              4
# Make                                    5
# Model                                  15
# Vehicle_Class                          15
# Motor                                  15
# Transmission                           15
# Fuel_Type                              15
# Eletric_Consumption_City(kWh100km)     15
# Eletric_Consumption_Hwy(kWh/100km)     15
# Eletric_Consumption_Comb(kWh/100km)    15
# Fuel_Consumption_City(Le/100km)        15
# Fuel_Consumption_Hwy(Le/100km)         15
# Fuel_Consumption_Comb(Le/100km)        15
# Range(km)                              15
# CO2_Emissions_(g/km)                   15
# CO2_Rating                             49
# Smog_Rating                            76
# Recharge_time(h)                       15
# dtype: int64

# %%
Battery_Operated.tail(16)

#to remove the dataset information after the last row of the dataset
# Out:
#                                             Model_Year  \
# 310                                             2022.0
# 311                                                NaN
# 312  Note: Vehicle manufacturers now use the 5-cycl...
# 313  that are more representative of a vehicle’s on...
# 314                                                NaN
# 315                            Understanding the table
# 316                                       Transmission
# 317                                                NaN
# 318                                          Fuel type
# 319                                        Consumption
# 320                                                NaN
# 321                                      CO2 emissions
# 322                                         CO2 rating
# 323                                        Smog rating
# 324                                              Range
# 325                                      Recharge time
#
# ...

# %%
Battery_Operated.drop(Battery_Operated.index[310:], inplace = True);
Battery_Operated.tail(16)
# Out:
#     Model_Year        Make                       Model  Vehicle_Class  Motor  \
# 295     2022.0       Tesla                 Model 3 RWD       Mid-size  191.0
# 296     2022.0       Tesla      Model 3 Long Range AWD       Mid-size  293.0
# 297     2022.0       Tesla         Model 3 Performance       Mid-size  321.0
# 298     2022.0       Tesla                     Model S      Full-size  494.0
# 299     2022.0       Tesla  Model S Plaid (19" Wheels)      Full-size  750.0
# 300     2022.0       Tesla  Model S Plaid (21" Wheels)      Full-size  750.0
# 301     2022.0       Tesla                     Model X  SUV: Standard  494.0
# 302     2022.0       Tesla  Model X Plaid (20" Wheels)  SUV: Standard  750.0
# 303     2022.0       Tesla  Model X Plaid (22" Wheels)  SUV: Standard  750.0
# 304     2022.0       Tesla                 Model Y AWD     SUV: Small  291.0
# 305     2022.0       Tesla      Model Y Long Range AWD     SUV: Small  291.0
# ...

# %%
Battery_Operated['Model_Year'] = Battery_Operated['Model_Year'].astype(int).astype(str)
Battery_Operated['Motor'] = Battery_Operated['Motor'].astype(int)
Battery_Operated['CO2_Rating'] = Battery_Operated['CO2_Rating'].convert_dtypes(convert_integer = True)
Battery_Operated['Smog_Rating'] = Battery_Operated['Smog_Rating'].convert_dtypes(convert_integer = True);
Battery_Operated
#to remove the decimal for some columns
# Out:
#     Model_Year        Make                Model Vehicle_Class  Motor  \
# 1         2012  Mitsubishi               i-MiEV    Subcompact     49
# 2         2012      Nissan                 LEAF      Mid-size     80
# 3         2013        Ford       Focus Electric       Compact    107
# 4         2013  Mitsubishi               i-MiEV    Subcompact     49
# 5         2013      Nissan                 LEAF      Mid-size     80
# ..         ...         ...                  ...           ...    ...
# 306       2022       Tesla  Model Y Performance    SUV: Small    312
# 307       2022  Volkswagen             ID.4 Pro    SUV: Small    150
# 308       2022  Volkswagen         ID.4 AWD Pro    SUV: Small    220
# 309       2022       Volvo    C40 Recharge Twin    SUV: Small    300
# 310       2022       Volvo   XC40 Recharge Twin    SUV: Small    300
#
#     Transmission Fuel_Type Eletric_Consumption_City(kWh100km)  \
# 1             A1         B                               16.9
# ...

# %%
Battery_Operated.isnull().sum()
# Out:
# Model_Year                              0
# Make                                    0
# Model                                   0
# Vehicle_Class                           0
# Motor                                   0
# Transmission                            0
# Fuel_Type                               0
# Eletric_Consumption_City(kWh100km)      0
# Eletric_Consumption_Hwy(kWh/100km)      0
# Eletric_Consumption_Comb(kWh/100km)     0
# Fuel_Consumption_City(Le/100km)         0
# Fuel_Consumption_Hwy(Le/100km)          0
# Fuel_Consumption_Comb(Le/100km)         0
# Range(km)                               0
# CO2_Emissions_(g/km)                    0
# CO2_Rating                             34
# Smog_Rating                            61
# Recharge_time(h)                        0
# dtype: int64

# %%
Battery_Operated.dropna(0, inplace=True)
# Out:
# <ipython-input-329-03582c841857>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   Battery_Operated.dropna(0, inplace=True)

# %%
Battery_Operated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249 entries, 62 to 310
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Model_Year                           249 non-null    object
#  1   Make                                 249 non-null    object
#  2   Model                                249 non-null    object
#  3   Vehicle_Class                        249 non-null    object
#  4   Motor                                249 non-null    int64
#  5   Transmission                         249 non-null    object
#  6   Fuel_Type                            249 non-null    object
#  7   Eletric_Consumption_City(kWh100km)   249 non-null    object
#  8   Eletric_Consumption_Hwy(kWh/100km)   249 non-null    object
#  9   Eletric_Consumption_Comb(kWh/100km)  249 non-null    object
#  10  Fuel_Consumption_City(Le/100km)      249 non-null    object
# ...

# %%
Battery_Operated[Battery_Operated['CO2_Rating'].isna()] 

#NA from the rating columns are from the years before 2020 which are not needed for the analysis
# Out:
# Empty DataFrame
# Columns: [Model_Year, Make, Model, Vehicle_Class, Motor, Transmission, Fuel_Type, Eletric_Consumption_City(kWh100km), Eletric_Consumption_Hwy(kWh/100km), Eletric_Consumption_Comb(kWh/100km), Fuel_Consumption_City(Le/100km), Fuel_Consumption_Hwy(Le/100km), Fuel_Consumption_Comb(Le/100km), Range(km), CO2_Emissions_(g/km), CO2_Rating, Smog_Rating, Recharge_time(h)]
# Index: []

# %%
Battery_Operated.isnull().sum()

#all null rows are not removed
# Out:
# Model_Year                             0
# Make                                   0
# Model                                  0
# Vehicle_Class                          0
# Motor                                  0
# Transmission                           0
# Fuel_Type                              0
# Eletric_Consumption_City(kWh100km)     0
# Eletric_Consumption_Hwy(kWh/100km)     0
# Eletric_Consumption_Comb(kWh/100km)    0
# Fuel_Consumption_City(Le/100km)        0
# Fuel_Consumption_Hwy(Le/100km)         0
# Fuel_Consumption_Comb(Le/100km)        0
# Range(km)                              0
# CO2_Emissions_(g/km)                   0
# CO2_Rating                             0
# Smog_Rating                            0
# Recharge_time(h)                       0
# dtype: int64

# %%
Battery_Operated.to_excel(r'drive\MyDrive\DAB103-DEMO\DAB103_Project\Battery_Operated.xlsx', index=False)

# %% [markdown]
# MY2012-2022 Plug-in Hybrid Electric Vehicles.xlsx
#
# Hybrid_Vehicles

# %%
Hybrid_Vehicles
# Out:
#              Model                                               Make  \
# 0             Year                                                NaN
# 1             2012                                          Chevrolet
# 2             2013                                          Chevrolet
# 3             2013                                               Ford
# 4             2013                                               Ford
# ..             ...                                                ...
# 234          Range  the estimated driving distance (in kilometres)...
# 235  Recharge time  the estimated time (in hours) to fully recharg...
# 236  CO2 emissions  The vehicle's tailpipe emissions of carbon dio...
# 237     CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 238    Smog rating  the tailpipe emissions of smog-forming polluta...
#
#            Model.1 Vehicle Class Motor Engine Size  Cylinders Transmission  \
# ...

# %%
Hybrid_Vehicles.rename(columns = {'Model': 'Model_Year',
                                    'Model.1': 'Model',
                                    'Engine Size': 'Engine Size (L)',
                                    'Fuel': 'Fuel Type 1',
                                    'Consumption': 'Consumption Combined Combined Le/100 km', 
                                    'Range 1': 'Range 1',
                                    'Recharge': 'Recharge Time (h)',
                                    'Fuel.1': 'Fule Type 2',
                                    'Consumption.1': 'Fuel Consumption City(L/100km)',
                                    'Unnamed: 14': 'Fuel Consumption Hwy(L/100km)',
                                    'Unnamed: 15': 'Fuel Consumption Comb(L/100km)',
                                    'Range 2 ': 'Range 2',
                                    'CO2 Emissions': 'CO2 Emissions (g/km)',
                                    'CO2 ': 'CO2 Rating',
                                    'Smog': 'Smog Rating'}, inplace = True)

Hybrid_Vehicles.columns = Hybrid_Vehicles.columns.str.replace(' ', "_")                       

Hybrid_Vehicles.drop(Hybrid_Vehicles.index[0:1], inplace = True); Hybrid_Vehicles
# Out:
#         Model_Year                                               Make  \
# 1             2012                                          Chevrolet
# 2             2013                                          Chevrolet
# 3             2013                                               Ford
# 4             2013                                               Ford
# 5             2013                                             Toyota
# ..             ...                                                ...
# 234          Range  the estimated driving distance (in kilometres)...
# 235  Recharge time  the estimated time (in hours) to fully recharg...
# 236  CO2 emissions  The vehicle's tailpipe emissions of carbon dio...
# 237     CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 238    Smog rating  the tailpipe emissions of smog-forming polluta...
#
#                     Model Vehicle_Class Motor Engine_Size_(L)  Cylinders  \
# ...

# %%
Hybrid_Vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238 entries, 1 to 238
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Model_Year                               229 non-null    object
#  1   Make                                     232 non-null    object
#  2   Model                                    217 non-null    object
#  3   Vehicle_Class                            217 non-null    object
#  4   Motor                                    217 non-null    object
#  5   Engine_Size_(L)                          217 non-null    object
#  6   Cylinders                                217 non-null    float64
#  7   Transmission                             217 non-null    object
#  8   Fuel_Type_1                              217 non-null    object
#  9   Consumption_Combined_Combined_Le/100_km  218 non-null    object
# ...

# %%
Hybrid_Vehicles.tail(25)
# Out:
#                                             Model_Year  \
# 214                                               2022
# 215                                               2022
# 216                                               2022
# 217                                               2022
# 218                                                NaN
# 219  *In testing, this vehicle did not use any gaso...
# 220  Note: Vehicle manufacturers now use the 5-cycl...
# 221  that are more representative of a vehicle’s on...
# 222                                                NaN
# 223                            Understanding the table
# 224                                       Transmission
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229                                          Fuel type
# ...

# %%
Hybrid_Vehicles.drop(Hybrid_Vehicles.index[217:], inplace = True)
Hybrid_Vehicles.tail(5)
# Out:
#     Model_Year   Make                                Model  \
# 213       2022  Volvo   V60 T8 AWD Recharge Extended Range
# 214       2022  Volvo                 XC60 T8 AWD Recharge
# 215       2022  Volvo  XC60 T8 AWD Recharge Extended Range
# 216       2022  Volvo                 XC90 T8 AWD Recharge
# 217       2022  Volvo  XC90 T8 AWD Recharge Extended Range
#
#             Vehicle_Class Motor Engine_Size_(L)  Cylinders Transmission  \
# 213  Station wagon: Small   107               2        4.0          AS8
# 214            SUV: Small    65               2        4.0          AS8
# 215            SUV: Small   107               2        4.0          AS8
# 216         SUV: Standard    65               2        4.0          AS8
# 217         SUV: Standard   107               2        4.0          AS8
#
#     Fuel_Type_1 Consumption_Combined_Combined_Le/100_km Range_1  \
# 213        B/Z*         3.0 ([27.2 kWh + 0.0 L]/100 km)      64
# ...

# %%
Hybrid_Vehicles.isnull().sum()
# Out:
# Model_Year                                  0
# Make                                        0
# Model                                       0
# Vehicle_Class                               0
# Motor                                       0
# Engine_Size_(L)                             0
# Cylinders                                   0
# Transmission                                0
# Fuel_Type_1                                 0
# Consumption_Combined_Combined_Le/100_km     0
# Range_1                                     0
# Recharge_Time_(h)                           0
# Fule_Type_2                                 0
# Fuel_Consumption_City(L/100km)              0
# Fuel_Consumption_Hwy(L/100km)               0
# Fuel_Consumption_Comb(L/100km)              0
# Range_2                                     0
# CO2_Emissions_(g/km)                        0
# CO2                                        20
# Smog_Rating                                36
# dtype: int64

# %%
Hybrid_Vehicles.dropna(0, inplace=True)
# Out:
# <ipython-input-340-03dcc6ec709a>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   Hybrid_Vehicles.dropna(0, inplace=True)

# %%
Hybrid_Vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 37 to 217
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Model_Year                               181 non-null    object
#  1   Make                                     181 non-null    object
#  2   Model                                    181 non-null    object
#  3   Vehicle_Class                            181 non-null    object
#  4   Motor                                    181 non-null    object
#  5   Engine_Size_(L)                          181 non-null    object
#  6   Cylinders                                181 non-null    float64
#  7   Transmission                             181 non-null    object
#  8   Fuel_Type_1                              181 non-null    object
#  9   Consumption_Combined_Combined_Le/100_km  181 non-null    object
# ...

# %%
Hybrid_Vehicles['Model_Year'] = Hybrid_Vehicles['Model_Year'].astype(str); Hybrid_Vehicles
# Out:
#     Model_Year   Make                                Model  \
# 37        2017   Audi                            A3 e-tron
# 38        2017    BMW                                 330e
# 39        2017    BMW                          740e xDrive
# 40        2017    BMW                       i3 REx (94 Ah)
# 41        2017    BMW                                   i8
# ..         ...    ...                                  ...
# 213       2022  Volvo   V60 T8 AWD Recharge Extended Range
# 214       2022  Volvo                 XC60 T8 AWD Recharge
# 215       2022  Volvo  XC60 T8 AWD Recharge Extended Range
# 216       2022  Volvo                 XC90 T8 AWD Recharge
# 217       2022  Volvo  XC90 T8 AWD Recharge Extended Range
#
#             Vehicle_Class Motor Engine_Size_(L)  Cylinders Transmission  \
# 37                Compact    80             1.4        4.0           A6
# 38                Compact    65               2        4.0          AS8
# ...

# %%
Hybrid_Vehicles.isnull().sum()
# Out:
# Model_Year                                 0
# Make                                       0
# Model                                      0
# Vehicle_Class                              0
# Motor                                      0
# Engine_Size_(L)                            0
# Cylinders                                  0
# Transmission                               0
# Fuel_Type_1                                0
# Consumption_Combined_Combined_Le/100_km    0
# Range_1                                    0
# Recharge_Time_(h)                          0
# Fule_Type_2                                0
# Fuel_Consumption_City(L/100km)             0
# Fuel_Consumption_Hwy(L/100km)              0
# Fuel_Consumption_Comb(L/100km)             0
# Range_2                                    0
# CO2_Emissions_(g/km)                       0
# CO2                                        0
# Smog_Rating                                0
# dtype: int64

# %%
Hybrid_Vehicles.to_excel(r'drive/MyDrive/DAB103-DEMO/DAB103_Project/Hybrid_Vehicles.xlsx', index=False)

# %% [markdown]
# MY2022 Gas Powered Fuel Consumption Ratings.xlsx
#
# Gas_Powered

# %%
Gas_Powered
# Out:
#                 Model                                               Make  \
# 0                Year                                                NaN
# 1              2022.0                                              Acura
# 2              2022.0                                              Acura
# 3              2022.0                                              Acura
# 4              2022.0                                              Acura
# ..                ...                                                ...
# 974               NaN                                    N = natural gas
# 975  Fuel consumption  City and highway fuel consumption ratings are ...
# 976     CO2 emissions  the tailpipe emissions of carbon dioxide (in g...
# 977        CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 978       Smog rating  the tailpipe emissions of smog-forming polluta...
#
#                Model.1 Vehicle Class Engine Size  Cylinders Transmission  \
# ...

# %%
Gas_Powered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Model             964 non-null    object
#  1   Make              976 non-null    object
#  2   Model.1           955 non-null    object
#  3   Vehicle Class     955 non-null    object
#  4   Engine Size       956 non-null    object
#  5   Cylinders         955 non-null    float64
#  6   Transmission      955 non-null    object
#  7   Fuel              956 non-null    object
#  8   Fuel Consumption  956 non-null    object
#  9   Unnamed: 9        956 non-null    object
#  10  Unnamed: 10       956 non-null    object
#  11  Unnamed: 11       956 non-null    object
#  12  CO2 Emissions     956 non-null    object
#  13  CO2               956 non-null    object
#  14  Smog              956 non-null    object
# dtypes: float64(1), object(14)
# memory usage: 114.9+ KB

# %%
Gas_Powered.rename(columns = {'Model': 'Model Year', 
                              'Model.1': 'Model',
                              'Engine Size': 'Engine Size (L)',
                              'Fuel': 'Fuel Type',
                              'Fuel Consumption': 'Fuel Consumption City(L/100km)',                                    
                              'Unnamed: 9': 'Fuel Consumption Hwy(L/100km)',
                              'Unnamed: 10': 'Fuel Consumption Comb(L/100km)',
                              'Unnamed: 11': 'Fuel Consumption Comb(mpg)',
                              'CO2': 'CO2 Rating'  ,                                
                              'CO2 Emissions': 'CO2 Emissions (g/km)',                                    
                              'Smog': 'Smog Rating',}, inplace = True)

#to rename columns

Gas_Powered.columns = Gas_Powered.columns.str.replace(' ', "_")                          

Gas_Powered.drop(Gas_Powered.index[0:1], inplace = True); Gas_Powered
# Out:
#            Model_Year                                               Make  \
# 1              2022.0                                              Acura
# 2              2022.0                                              Acura
# 3              2022.0                                              Acura
# 4              2022.0                                              Acura
# 5              2022.0                                              Acura
# ..                ...                                                ...
# 974               NaN                                    N = natural gas
# 975  Fuel consumption  City and highway fuel consumption ratings are ...
# 976     CO2 emissions  the tailpipe emissions of carbon dioxide (in g...
# 977        CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 978       Smog rating  the tailpipe emissions of smog-forming polluta...
#
#                  Model Vehicle_Class Engine_Size_(L)  Cylinders Transmission  \
# ...

# %% [markdown]
# Changing Year data type from float to integer so .0 is removed from
#
# *   List item
# *   List item
#
# the Year column. Similary in CO2 Rating and Smog Rating column

# %%
Gas_Powered['Model_Year'] = Gas_Powered['Model_Year'].convert_dtypes(convert_integer=True)
Gas_Powered['CO2_Rating'] = Gas_Powered['CO2_Rating'].convert_dtypes(convert_integer=True)
Gas_Powered['Smog_Rating'] = Gas_Powered['Smog_Rating'].convert_dtypes(convert_integer=True)
Gas_Powered
# Out:
#            Model_Year                                               Make  \
# 1              2022.0                                              Acura
# 2              2022.0                                              Acura
# 3              2022.0                                              Acura
# 4              2022.0                                              Acura
# 5              2022.0                                              Acura
# ..                ...                                                ...
# 974               NaN                                    N = natural gas
# 975  Fuel consumption  City and highway fuel consumption ratings are ...
# 976     CO2 emissions  the tailpipe emissions of carbon dioxide (in g...
# 977        CO2 rating  the tailpipe emissions of carbon dioxide rated...
# 978       Smog rating  the tailpipe emissions of smog-forming polluta...
#
#                  Model Vehicle_Class Engine_Size_(L)  Cylinders Transmission  \
# ...

# %%
Gas_Powered.tail(25)
# Out:
#                   Model_Year  \
# 954                   2022.0
# 955                   2022.0
# 956                      NaN
# 957  Understanding the table
# 958                    Model
# 959                      NaN
# 960                      NaN
# 961                      NaN
# 962                      NaN
# 963                      NaN
# 964             Transmission
# 965                      NaN
# 966                      NaN
# 967                      NaN
# 968                      NaN
# 969                      NaN
# 970                Fuel type
# 971                      NaN
# 972                      NaN
# 973                      NaN
# 974                      NaN
# 975         Fuel consumption
# 976            CO2 emissions
# 977               CO2 rating
# 978              Smog rating
#
#                                                   Make        Model  \
# 954                                              Volvo  XC90 T5 AWD
# ...

# %% [markdown]
# Below we removed the description text for the dataset that was alredy present from rows 956 onwards.

# %%
Gas_Powered.drop(Gas_Powered.index[956:], inplace = True)

# %%
Gas_Powered.tail(25)
# Out:
#     Model_Year        Make                  Model            Vehicle_Class  \
# 932     2022.0  Volkswagen               Golf GTI                 Mid-size
# 933     2022.0  Volkswagen                 Golf R                 Mid-size
# 934     2022.0  Volkswagen                 Golf R                 Mid-size
# 935     2022.0  Volkswagen                  Jetta                  Compact
# 936     2022.0  Volkswagen                  Jetta                  Compact
# 937     2022.0  Volkswagen              Jetta GLI                  Compact
# 938     2022.0  Volkswagen              Jetta GLI                  Compact
# 939     2022.0  Volkswagen                 Passat                 Mid-size
# 940     2022.0  Volkswagen                   Taos               SUV: Small
# 941     2022.0  Volkswagen           Taos 4MOTION               SUV: Small
# 942     2022.0  Volkswagen         Tiguan 4MOTION               SUV: Small
# ...

# %%
Gas_Powered.dropna(0, inplace=True)
# Out:
# <ipython-input-352-4bc507cbf105>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   Gas_Powered.dropna(0, inplace=True)

# %%
Gas_Powered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 955 entries, 1 to 955
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Model_Year                      955 non-null    object
#  1   Make                            955 non-null    object
#  2   Model                           955 non-null    object
#  3   Vehicle_Class                   955 non-null    object
#  4   Engine_Size_(L)                 955 non-null    object
#  5   Cylinders                       955 non-null    float64
#  6   Transmission                    955 non-null    object
#  7   Fuel_Type                       955 non-null    object
#  8   Fuel_Consumption_City(L/100km)  955 non-null    object
#  9   Fuel_Consumption_Hwy(L/100km)   955 non-null    object
#  10  Fuel_Consumption_Comb(L/100km)  955 non-null    object
#  11  Fuel_Consumption_Comb(mpg)      955 non-null    object
# ...

# %%
Gas_Consumption = Gas_Powered.groupby(['Vehicle_Class'])['Fuel_Consumption_Comb(L/100km)'].mean(); Gas_Consumption
# Out:
# Vehicle_Class
# Compact                     8.878571
# Full-size                  10.920313
# Mid-size                    9.805128
# Minicompact                12.012245
# Minivan                     9.671429
# Pickup truck: Small        11.135000
# Pickup truck: Standard     13.605310
# SUV: Small                  9.780711
# SUV: Standard              12.938255
# Special purpose vehicle    10.775000
# Station wagon: Mid-size    12.200000
# Station wagon: Small        8.205263
# Subcompact                 10.624051
# Two-seater                 13.139216
# Name: Fuel_Consumption_Comb(L/100km), dtype: float64

# %%
Gas_Powered.to_excel(r'drive/MyDrive/DAB103-DEMO/DAB103_Project/Gas_Powered.xlsx', index=False)

# %% [markdown]
# NEWYORK_DATA.csv
#
# New York Data

# %%
Lease_Purchase
# Out:
#       Data through Date Submitted Date   Make    Model       County    ZIP  \
# 0            02/29/2020     01/13/2018   Ford    Focus  Westchester  10598
# 1            02/29/2020     09/25/2017   Ford    Focus       Oneida  13601
# 2            02/29/2020     04/26/2018   Ford    Focus      Suffolk  11776
# 3            02/29/2020     08/30/2017   Ford    Focus       Nassau  11756
# 4            02/29/2020     05/29/2018   Ford    Focus     Onondaga  13039
# ...                 ...            ...    ...      ...          ...    ...
# 23169        02/29/2020     12/27/2017  Volvo  XC60 T8     Onondaga  13039
# 23170        02/29/2020     05/29/2018  Volvo  XC60 T8       Nassau  11791
# 23171        02/29/2020     09/25/2017  Volvo  XC90 T8      Niagara  14094
# 23172        02/29/2020     11/01/2017  Volvo  XC90 T8         Erie  14051
# 23173        02/29/2020     11/22/2017  Volvo  XC90 T8       Monroe  14580
#
# ...

# %%
Lease_Purchase['Year'] = pd.DatetimeIndex(Lease_Purchase['Submitted Date']).year
Type = Lease_Purchase.rename(columns = {'EV Type':'Type'}, inplace = True)
Lease_Purchase.Type
evBEV = Lease_Purchase[Lease_Purchase.Type == 'BEV']
evPHEV = Lease_Purchase[Lease_Purchase.Type == 'PHEV']

# %%
Lease_Purchase.notnull()
# Out:
#        Data through Date  Submitted Date  Make  Model  County   ZIP  Type  \
# 0                   True            True  True   True    True  True  True
# 1                   True            True  True   True    True  True  True
# 2                   True            True  True   True    True  True  True
# 3                   True            True  True   True    True  True  True
# 4                   True            True  True   True    True  True  True
# ...                  ...             ...   ...    ...     ...   ...   ...
# 23169               True            True  True   True    True  True  True
# 23170               True            True  True   True    True  True  True
# 23171               True            True  True   True    True  True  True
# 23172               True            True  True   True    True  True  True
# 23173               True            True  True   True    True  True  True
#
#        Transaction Type  Annual GHG Emissions Reductions (MT CO2e)  \
# ...

# %%
type(Lease_Purchase)
# Out:
# pandas.core.frame.DataFrame

# %%
Lease_Purchase['Make']
# Out:
# 0         Ford
# 1         Ford
# 2         Ford
# 3         Ford
# 4         Ford
#          ...
# 23169    Volvo
# 23170    Volvo
# 23171    Volvo
# 23172    Volvo
# 23173    Volvo
# Name: Make, Length: 23174, dtype: object

# %%
# Creating dataset
cars = ['Annual Petroleum Reductions (gallons)', 'Annual GHG Emissions Reductions (MT CO2e)']
 
data = [63,37]
 
# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars)
 
# show plot
plt.show()

# %%
print(Lease_Purchase.County.unique())
# Out:
# ['Westchester' 'Oneida' 'Suffolk' 'Nassau' 'Onondaga' 'Richmond'
#  'Dutchess' 'Rockland' 'Lewis' 'Steuben' 'Schenectady' 'Ulster' 'Albany'
#  'Chenango' 'Broome' 'Erie' 'Columbia' 'Kings' 'Putnam' 'Washington'
#  'Warren' 'Bronx' 'Queens' 'Saratoga' 'Essex' 'Niagara' 'Monroe' 'Orange'
#  'Jefferson' 'Oswego' 'New York' 'Rensselaer' 'Genesee' 'Wayne' 'Tompkins'
#  'Ontario' 'Clinton' 'Cayuga' 'Livingston' 'Schuyler' 'Chemung' 'Otsego'
#  'Cattaraugus' 'Sullivan' 'Montgomery' 'Delaware' 'Chautauqua' 'Tioga'
#  'Greene' 'Orleans' 'Allegany' 'Yates' 'Seneca' 'St. Lawrence' 'Madison'
#  'Schoharie' 'Herkimer' 'Hamilton' 'Wyoming' 'Fulton' 'Cortland'
#  'Franklin']

# %%
print(Lease_Purchase.Make.unique())
# Out:
# ['Ford' 'Chevrolet' 'Nissan' 'Chrysler' 'Mercedes-Benz' 'BMW' 'Tesla'
#  'Mitsubishi' 'Subaru' 'Honda' 'Toyota' 'Hyundai' 'Kia' 'Volvo' 'Jaguar'
#  'Audi' 'Smart' 'MINI' 'Porsche' 'Volkswagen']

# %%
Lease_Purchase.to_excel(r'drive/MyDrive/DAB103-DEMO/DAB103_Project/Lease_Purchase.xlsx', index=False)

# %% [markdown]
# #Q1-In terms of liters of gas per 100 km, how does electric vehicles consumption compare to the gas powered vehicles?

# %% [markdown]
# The fuel consumption for each category is explained in graphical representatioin below. To get the comparison, the data shows the fuel consumption for gas powered and Plug-in Hybrid Electric Vehicles by converting the electricity utilization to fuel, which is ***One litre of gasoline contains the energy equivalent to 8.9 kWh of electricity***
#
# By the results of visualization, the fuel usage is high in Hybrid vehicles in comparison to battery powered vehicles. This is due to the fact that electricity is consumed more in Hybrid vehicles and to get the difference between them, the elctricity is converted into fuel as explained above.

# %%
Battery_Consumption = Battery_Operated.groupby(['Vehicle_Class'])['Fuel_Consumption_Comb(Le/100km)'].mean(); Battery_Consumption
# Out:
# Vehicle_Class
# Compact                   2.822222
# Full-size                 2.213636
# Mid-size                  2.203333
# Pickup truck: Standard    3.400000
# SUV: Small                2.365625
# SUV: Standard             2.702500
# Station wagon: Small      2.162069
# Subcompact                2.183333
# Two-seater                2.250000
# Name: Fuel_Consumption_Comb(Le/100km), dtype: float64

# %% [markdown]
# The above graph represents the consumption of fuel in **Battery Operated** vehicles of different type. The **Pickup Trucks** and **Compact Vehicles** have the most usage of Fuel. The visulaization shows the consumption of fuel with taking the combination of consumption of fuel in city and on highway.

# %%
Hybrid_Consumption = Hybrid_Vehicles.groupby(['Vehicle_Class'])['Fuel_Consumption_Comb(L/100km)'].mean(); Hybrid_Consumption
# Out:
# Vehicle_Class
# Compact                  7.750000
# Full-size               10.505556
# Mid-size                 6.646667
# Minicompact              9.200000
# Minivan                  7.766667
# SUV: Small               8.313889
# SUV: Standard           10.596154
# Station wagon: Small     6.425000
# Subcompact               8.815789
# Two-seater               8.700000
# Name: Fuel_Consumption_Comb(L/100km), dtype: float64

# %% [markdown]
# The above graph represents the consumption of fuel in **Hybrid Operated** vehicles of different type. The **Full Size** and **SUV Standard** have the most usage of Fuel. The visulaization shows the consumption of fuel with taking the combination of consumption of fuel in city and on highway.

# %%
Gas_Consumption = Gas_Powered.groupby(['Vehicle_Class'])['Fuel_Consumption_Comb(L/100km)'].mean(); Gas_Consumption
# Out:
# Vehicle_Class
# Compact                     8.878571
# Full-size                  10.920313
# Mid-size                    9.805128
# Minicompact                12.012245
# Minivan                     9.671429
# Pickup truck: Small        11.135000
# Pickup truck: Standard     13.605310
# SUV: Small                  9.780711
# SUV: Standard              12.938255
# Special purpose vehicle    10.775000
# Station wagon: Mid-size    12.200000
# Station wagon: Small        8.205263
# Subcompact                 10.624051
# Two-seater                 13.139216
# Name: Fuel_Consumption_Comb(L/100km), dtype: float64

# %%
Hybrid_subset = Hybrid_Vehicles[['Vehicle_Class','Fuel_Consumption_Comb(L/100km)']]
Hybrid_subset.rename(columns = {'Fuel_Consumption_Comb(L/100km)': 'Fuel_Consumption_Comb'}, inplace = True)

Battery_subset = Battery_Operated[['Vehicle_Class','Fuel_Consumption_Comb(Le/100km)']]
Battery_subset.rename(columns = {'Fuel_Consumption_Comb(Le/100km)': 'Fuel_Consumption_Comb'}, inplace = True)

Gaspowered_subset = Gas_Powered[['Vehicle_Class','Fuel_Consumption_Comb(L/100km)']]
Gaspowered_subset.rename(columns = {'Fuel_Consumption_Comb(L/100km)': 'Fuel_Consumption_Comb'}, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
plt.bar(Gaspowered_subset.Vehicle_Class, Gaspowered_subset.Fuel_Consumption_Comb,label='Gas_powered_Consumption (L/100km)',color='#CCCCCC')
plt.bar(Hybrid_subset.Vehicle_Class, Hybrid_subset.Fuel_Consumption_Comb, label ='Hybrid_Fuel_Consumption(L/100km)', color='#99FF99')
plt.bar(Battery_subset.Vehicle_Class, Battery_subset.Fuel_Consumption_Comb, label="Battery_powered_Consumption (L/100km)", color='#3366FF')
plt.legend(loc="upper left")
plt.xticks(rotation=90)
plt.plot(kind='bar', stacked=True)
plt.xlabel("Vehicle_class") 
plt.ylabel("Consumption for city-hwy combined(L/100km)") 
plt.title("Consumption of fuel(in Battery, Fuel, & Gas)",size=15,fontweight="bold") 
plt.legend(bbox_to_anchor=(1.8, 1)) 
plt.show()

# %% [markdown]
# The above graph represents the consumption of fuel in **Gas Operated** vehicles of different type. The **Pickup Trucks** and **Two Vehicles** have the most usage of Fuel. The visulaization shows the consumption of fuel with taking the combination of consumption of fuel in city and on highway.

# %% [markdown]
# #Q2-From the year 2017 to 2020, what is the consumer preference trend in terms of purchasing and leasing Electric Vehicles?

# %% [markdown]
# Customers prefer to purchase than to lease electric vehicles. 13,359 people are inclined towards purchasing the electric vehicle between 2017 and 2020.
# Based on the visualization, there is an increase in the purchase and lease of Battery-operated electric vehicle in 2019 (approximate 194% and 152%, respectively), and for Plug-in Hybrid vehicle the trend for purchase and lease increased in 2018 (approximate 67% and 100%, respectively).

# %%
PB = (Lease_Purchase['Type']) .value_counts()
print(PB)
# Out:
# PHEV    14436
# BEV      8738
# Name: Type, dtype: int64

# %%
PL = (Lease_Purchase['Transaction Type']) .value_counts()
print(PL)
# Out:
# Purchase    13359
# Lease        9815
# Name: Transaction Type, dtype: int64

# %%
ev2=evBEV.groupby(['Year','Type','Transaction Type',]).size()
ev2=ev2.unstack()
ev2.plot(kind='line', ylabel = 'Vehicles Count', title = 'Purchase & Lease of BEV Vehicles', figsize =[16,5], color =['#99FF99','#3366FF'])
plt.show()
ev2=evPHEV.groupby(['Year','Type','Transaction Type']).size()
ev2=ev2.unstack()
ev2.plot(kind='line', ylabel = 'Vehicles Count', title = 'Purchase & Lease of PHEV Vehicles', figsize =[16,5], color =['#99FF99','#3366FF'])
plt.show()

# %% [markdown]
# #Q3-What is the range (capacity of distance traveled in km) between Plug-in Hybrid Electric Vehicles and Battery Electric Vehicles?

# %% [markdown]
# The visualization suggests that a vehicle's range changes based on the type of energy used.
# Hybrid vehicles range is greater compared to a battery-powered vehicle, as it has a longer range since they are powered by both, fuel and energy.
# For instance, for the Mid-size car type when it’s hybrid running on fuel, it has a range capacity of 995 km compared to the other category.

# %%
Battery_range =  Battery_Operated[['Make','Vehicle_Class','Range(km)']]

# %%
Battery_range=Battery_range.dropna(subset=['Vehicle_Class','Make'])

# %%
Battery_range.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249 entries, 62 to 310
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           249 non-null    object
#  1   Vehicle_Class  249 non-null    object
#  2   Range(km)      249 non-null    object
# dtypes: object(3)
# memory usage: 7.8+ KB

# %%
plt.figure(figsize=(10, 6))
sns.countplot(Battery_range['Vehicle_Class'],palette= ["#99FF99"])
plt.title('Range of Battery Operated Cars',size=18,fontweight="bold")
plt.xlabel('Vehicle_Class')
plt.xticks(rotation=90)
plt.ylabel('Range(km)')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Range(km)')

# %%
Battery_subset2 = Battery_Operated[['Vehicle_Class','Range(km)']]
Range_subset1 = Hybrid_Vehicles[['Vehicle_Class','Range_1']]
Range_subset2 = Hybrid_Vehicles[['Vehicle_Class','Range_2']]
Battery_subset2.rename(columns = {'Range(km)': 'Range'}, inplace = True)
Battery_subset2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#             Vehicle_Class  Range
# 62             Subcompact  130.0
# 63             Subcompact  183.0
# 64   Station wagon: Small  383.0
# 65                Compact  185.0
# 66               Mid-size  200.0
# ..                    ...    ...
# 306            SUV: Small  488.0
# 307            SUV: Small  422.0
# 308            SUV: Small  394.0
# 309            SUV: Small  364.0
# 310            SUV: Small  359.0
#
# [249 rows x 2 columns]

# %%
Range_subset1
Range_subset2
# Out:
#             Vehicle_Class Range_2
# 37                Compact     579
# 38                Compact     533
# 39              Full-size     525
# 40             Subcompact     129
# 41             Subcompact     509
# ..                    ...     ...
# 213  Station wagon: Small     792
# 214            SUV: Small     769
# 215            SUV: Small     838
# 216         SUV: Standard     813
# 217         SUV: Standard     798
#
# [181 rows x 2 columns]

# %%
plt.bar(Range_subset2.Vehicle_Class, Range_subset2.Range_2, label="Hybrid_Fuel_Range (km)", color='#99FF99')
plt.bar(Battery_subset2.Vehicle_Class, Battery_subset2.Range, label ='Battery_powered_Range(km)', color='#CCCCCC')
plt.bar(Range_subset1.Vehicle_Class, Range_subset1.Range_1,label='Hybrid_Electric_Range (km)', color='#3366FF')
plt.xticks(rotation=90)
plt.plot()

plt.xlabel("Vehicle_class")
plt.ylabel("Range in km")
plt.title("Range distribution in Hybrid Cars & Battery-operated Cars",size=13,fontweight="bold")
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# #Q4-Are Electric Vehicles better for the environment compare to Gas-Powered Vehicles in terms of the g/km of carbon emission?

# %% [markdown]
# The average CO2 emissions of gas-powered vehicles starts from 192.47 g/km which is higher than the average CO2 emissions of hybrid-electric vehicles that peaks at  150.5 g/km.
#
# Overall, the graphs shows that hybrid-electric and battery-operated vehicles would be more beneficial for the environment as it emits lower CO2.

# %%
Battery_Operated.isnull().sum()
# Out:
# Model_Year                             0
# Make                                   0
# Model                                  0
# Vehicle_Class                          0
# Motor                                  0
# Transmission                           0
# Fuel_Type                              0
# Eletric_Consumption_City(kWh100km)     0
# Eletric_Consumption_Hwy(kWh/100km)     0
# Eletric_Consumption_Comb(kWh/100km)    0
# Fuel_Consumption_City(Le/100km)        0
# Fuel_Consumption_Hwy(Le/100km)         0
# Fuel_Consumption_Comb(Le/100km)        0
# Range(km)                              0
# CO2_Emissions_(g/km)                   0
# CO2_Rating                             0
# Smog_Rating                            0
# Recharge_time(h)                       0
# dtype: int64

# %%
Battery_Operated_C02 = Battery_Operated.groupby(['Vehicle_Class'])['CO2_Emissions_(g/km)'].mean(); Battery_Operated_C02
# Out:
# Vehicle_Class
# Compact                   0.0
# Full-size                 0.0
# Mid-size                  0.0
# Pickup truck: Standard    0.0
# SUV: Small                0.0
# SUV: Standard             0.0
# Station wagon: Small      0.0
# Subcompact                0.0
# Two-seater                0.0
# Name: CO2_Emissions_(g/km), dtype: float64

# %%
Hybrid_Vehicles_CO2 = Hybrid_Vehicles.groupby(['Vehicle_Class'])['CO2_Emissions_(g/km)'].mean(); Hybrid_Vehicles_CO2
# Out:
# Vehicle_Class
# Compact                  95.750000
# Full-size               150.500000
# Mid-size                 75.622222
# Minicompact              54.000000
# Minivan                  71.333333
# SUV: Small               97.750000
# SUV: Standard           145.076923
# Station wagon: Small     70.500000
# Subcompact               53.000000
# Two-seater              118.000000
# Name: CO2_Emissions_(g/km), dtype: float64

# %%
Hybrid_Vehicles_CO2.plot(kind = 'bar',
               title = 'CO2 Emission by Hybrid Vehicles', 
               ylabel = 'CO2 (g/km)',
               xlabel = 'Vehicle Class',
               figsize = (10, 5),
               color='#99FF99')

# %%
Gas_Powered_CO2 = Gas_Powered.groupby(['Vehicle_Class'])['CO2_Emissions_(g/km)'].mean(); Gas_Powered_CO2
# Out:
# Vehicle_Class
# Compact                    207.700000
# Full-size                  256.734375
# Mid-size                   229.504274
# Minicompact                281.408163
# Minivan                    227.000000
# Pickup truck: Small        270.050000
# Pickup truck: Standard     309.495575
# SUV: Small                 229.857868
# SUV: Standard              305.174497
# Special purpose vehicle    237.500000
# Station wagon: Mid-size    285.375000
# Station wagon: Small       192.473684
# Subcompact                 248.341772
# Two-seater                 307.254902
# Name: CO2_Emissions_(g/km), dtype: float64

# %%
Gas_Powered_CO2.plot(kind = 'bar',
               title = 'CO2 Emission by Gas Powered Vehicles', 
               ylabel = 'CO2 (g/km)',
               xlabel = 'Vehicle Class',
               figsize = (10, 5),
               color='#3366FF')
